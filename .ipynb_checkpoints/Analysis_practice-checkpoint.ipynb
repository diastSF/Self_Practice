# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('EPL_Set.csv')
df.head()
# Out:
#   Div      Date     HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  HTR  \
# 0  E0  14/08/93      Arsenal        Coventry     0     3   A   NaN   NaN  NaN
# 1  E0  14/08/93  Aston Villa             QPR     4     1   H   NaN   NaN  NaN
# 2  E0  14/08/93      Chelsea       Blackburn     1     2   A   NaN   NaN  NaN
# 3  E0  14/08/93    Liverpool  Sheffield Weds     2     0   H   NaN   NaN  NaN
# 4  E0  14/08/93     Man City           Leeds     1     1   D   NaN   NaN  NaN
#
#     Season
# 0  1993-94
# 1  1993-94
# 2  1993-94
# 3  1993-94
# 4  1993-94

# %%
df.columns
# Out:
# Index(['Div', 'Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG',
#        'HTAG', 'HTR', 'Season'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9664 entries, 0 to 9663
# Data columns (total 11 columns):
# Div         9664 non-null object
# Date        9664 non-null object
# HomeTeam    9664 non-null object
# AwayTeam    9664 non-null object
# FTHG        9664 non-null int64
# FTAG        9664 non-null int64
# FTR         9664 non-null object
# HTHG        8740 non-null float64
# HTAG        8740 non-null float64
# HTR         8740 non-null object
# Season      9664 non-null object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 830.6+ KB

# %%
df['Season'].value_counts()
# Out:
# 1994-95    462
# 1993-94    462
# 2014-15    380
# 1999-00    380
# 2015-16    380
# 2009-10    380
# 2004-05    380
# 2003-04    380
# 2010-11    380
# 2008-09    380
# 2012-13    380
# 2007-08    380
# 2013-14    380
# 2000-01    380
# 2011-12    380
# 2002-03    380
# 1995-96    380
# 1996-97    380
# 2017-18    380
# 2001-02    380
# 2005-06    380
# 1997-98    380
# 1998-99    380
# 2006-07    380
# 2016-17    380
# Name: Season, dtype: int64

# %%
df[(df['HomeTeam'] == 'Liverpool') | (df['AwayTeam'] == 'Liverpool')]
# Out:
#      Div        Date          HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 3     E0    14/08/93         Liverpool  Sheffield Weds     2     0   H   NaN
# 19    E0    18/08/93               QPR       Liverpool     1     3   A   NaN
# 32    E0    22/08/93           Swindon       Liverpool     0     5   A   NaN
# 39    E0    25/08/93         Liverpool       Tottenham     1     2   A   NaN
# 48    E0    28/08/93         Liverpool           Leeds     2     0   H   NaN
# 60    E0    1/9/1993          Coventry       Liverpool     1     0   H   NaN
# 75    E0   12/9/1993         Liverpool       Blackburn     0     1   A   NaN
# 79    E0    18/09/93           Everton       Liverpool     2     0   H   NaN
# 90    E0    25/09/93           Chelsea       Liverpool     1     0   H   NaN
# 101   E0   2/10/1993         Liverpool         Arsenal     0     0   D   NaN
# 113   E0    16/10/93         Liverpool          Oldham     2     1   H   NaN
# ...

# %%
dfLiverpool = df[(df['HomeTeam'] == 'Liverpool') | (df['AwayTeam'] == 'Liverpool')].drop(['HTHG','HTAG','HTR'],axis=1)
dfLiverpool
# Out:
#      Div        Date          HomeTeam        AwayTeam  FTHG  FTAG FTR  \
# 3     E0    14/08/93         Liverpool  Sheffield Weds     2     0   H
# 19    E0    18/08/93               QPR       Liverpool     1     3   A
# 32    E0    22/08/93           Swindon       Liverpool     0     5   A
# 39    E0    25/08/93         Liverpool       Tottenham     1     2   A
# 48    E0    28/08/93         Liverpool           Leeds     2     0   H
# 60    E0    1/9/1993          Coventry       Liverpool     1     0   H
# 75    E0   12/9/1993         Liverpool       Blackburn     0     1   A
# 79    E0    18/09/93           Everton       Liverpool     2     0   H
# 90    E0    25/09/93           Chelsea       Liverpool     1     0   H
# 101   E0   2/10/1993         Liverpool         Arsenal     0     0   D
# 113   E0    16/10/93         Liverpool          Oldham     2     1   H
# 124   E0    23/10/93          Man City       Liverpool     1     1   D
# ...

# %%
dfLiverpool.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 958 entries, 3 to 9657
# Data columns (total 8 columns):
# Div         958 non-null object
# Date        958 non-null object
# HomeTeam    958 non-null object
# AwayTeam    958 non-null object
# FTHG        958 non-null int64
# FTAG        958 non-null int64
# FTR         958 non-null object
# Season      958 non-null object
# dtypes: int64(2), object(6)
# memory usage: 67.4+ KB

# %%
dfLivHome = dfLiverpool[dfLiverpool['HomeTeam'] == 'Liverpool']
dfLivHome
# Out:
#      Div        Date   HomeTeam          AwayTeam  FTHG  FTAG FTR   Season
# 3     E0    14/08/93  Liverpool    Sheffield Weds     2     0   H  1993-94
# 39    E0    25/08/93  Liverpool         Tottenham     1     2   A  1993-94
# 48    E0    28/08/93  Liverpool             Leeds     2     0   H  1993-94
# 75    E0   12/9/1993  Liverpool         Blackburn     0     1   A  1993-94
# 101   E0   2/10/1993  Liverpool           Arsenal     0     0   D  1993-94
# 113   E0    16/10/93  Liverpool            Oldham     2     1   H  1993-94
# 136   E0    30/10/93  Liverpool       Southampton     4     2   H  1993-94
# 147   E0   6/11/1993  Liverpool          West Ham     2     0   H  1993-94
# 184   E0    28/11/93  Liverpool       Aston Villa     2     1   H  1993-94
# 201   E0   8/12/1993  Liverpool               QPR     3     2   H  1993-94
# 207   E0  11/12/1993  Liverpool           Swindon     2     2   D  1993-94
# ...

# %%
dfLivAway = dfLiverpool[dfLiverpool['AwayTeam'] == 'Liverpool']
dfLivAway
# Out:
#      Div       Date          HomeTeam   AwayTeam  FTHG  FTAG FTR   Season
# 19    E0   18/08/93               QPR  Liverpool     1     3   A  1993-94
# 32    E0   22/08/93           Swindon  Liverpool     0     5   A  1993-94
# 60    E0   1/9/1993          Coventry  Liverpool     1     0   H  1993-94
# 79    E0   18/09/93           Everton  Liverpool     2     0   H  1993-94
# 90    E0   25/09/93           Chelsea  Liverpool     1     0   H  1993-94
# 124   E0   23/10/93          Man City  Liverpool     1     1   D  1993-94
# 164   E0   21/11/93         Newcastle  Liverpool     3     0   H  1993-94
# 192   E0  4/12/1993    Sheffield Weds  Liverpool     3     1   H  1993-94
# 223   E0   18/12/93         Tottenham  Liverpool     3     3   D  1993-94
# 228   E0   26/12/93  Sheffield United  Liverpool     0     0   D  1993-94
# 248   E0   1/1/1994           Ipswich  Liverpool     1     2   A  1993-94
# 269   E0   15/01/94            Oldham  Liverpool     0     3   A  1993-94
# ...

# %%
dfLivHome['FTR'].value_counts()
# Out:
# H    290
# D    123
# A     66
# Name: FTR, dtype: int64

# %%
dfLivHome.groupby('Season').count()
# Out:
#          Div  Date  HomeTeam  AwayTeam  FTHG  FTAG  FTR
# Season
# 1993-94   21    21        21        21    21    21   21
# 1994-95   21    21        21        21    21    21   21
# 1995-96   19    19        19        19    19    19   19
# 1996-97   19    19        19        19    19    19   19
# 1997-98   19    19        19        19    19    19   19
# 1998-99   19    19        19        19    19    19   19
# 1999-00   19    19        19        19    19    19   19
# 2000-01   19    19        19        19    19    19   19
# 2001-02   19    19        19        19    19    19   19
# 2002-03   19    19        19        19    19    19   19
# 2003-04   19    19        19        19    19    19   19
# 2004-05   19    19        19        19    19    19   19
# 2005-06   19    19        19        19    19    19   19
# 2006-07   19    19        19        19    19    19   19
# 2007-08   19    19        19        19    19    19   19
# 2008-09   19    19        19        19    19    19   19
# ...

# %%
dfLivHome.set_index('Season').head()
# Out:
#         Div       Date   HomeTeam        AwayTeam  FTHG  FTAG FTR
# Season
# 1993-94  E0   14/08/93  Liverpool  Sheffield Weds     2     0   H
# 1993-94  E0   25/08/93  Liverpool       Tottenham     1     2   A
# 1993-94  E0   28/08/93  Liverpool           Leeds     2     0   H
# 1993-94  E0  12/9/1993  Liverpool       Blackburn     0     1   A
# 1993-94  E0  2/10/1993  Liverpool         Arsenal     0     0   D

# %%
def result():
    if dfLivHome['FTR'] == 'H':
        return 'Win'
    elif dfLivHome['FTR'] == 'A':
        return 'Lose'
    else:
        return 'Draw'
    
dfLivHome['Result'] = result()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-abfadcaaf797> in <module>
#       6     else:
#       7         return 'Draw'
# ----> 8 dfLivHome['Result'] = result()
#
# <ipython-input-29-abfadcaaf797> in result()
#       1 def result():
# ----> 2     if dfLivHome['FTR'] == 'H':
#       3         return 'Win'
#       4     elif dfLivHome['FTR'] == 'A':
#       5         return 'Lose'
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1574         raise ValueError("The truth value of a {0} is ambiguous. "
#    1575                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1576                          .format(self.__class__.__name__))
#    1577
#    1578     __bool__ = __nonzero__
#
# ...

# %%
dfLivHome['FTR'] == 'H'
# Out:
# 3        True
# 39      False
# 48       True
# 75      False
# 101     False
# 113      True
# 136      True
# 147      True
# 184      True
# 201      True
# 207     False
# 237     False
# 262     False
# 279      True
# 315      True
# 339      True
# 347      True
# 380     False
# 398      True
# 408     False
# 436     False
# 493      True
# 507     False
# 541      True
# 550      True
# 573      True
# 602      True
# 611      True
# 632     False
# 658     False
#         ...
# 9088     True
# 9116    False
# 9127    False
# 9145     True
# 9163     True
# 9176     True
# 9191     True
# 9204    False
# 9232    False
# 9256    False
# 9279     True
# 9297     True
# 9311     True
# 9327    False
# 9356    False
# 9377     True
# 9399     True
# 9406    False
# 9441    False
# 9447    False
# 9477     True
# 9487     True
# 9512     True
# 9542    False
# 9558     True
# 9566     True
# 9586     True
# 9611     True
# 9631    False
# 9657     True
# ...
